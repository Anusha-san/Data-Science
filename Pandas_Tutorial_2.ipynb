# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusha-san/Data-Science/blob/main/Pandas_Tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np

# %%
#create data frame

#using list


df1 = [[1,2,3],[1,2,3],[7,8,9]]

df2 = pd.DataFrame(df1,columns=['roll','age','marks'])

# %%
df2.duplicated().sum()
# Out:
# 1

# %%
df2.rename(columns={'roll':'iq'},inplace=True)

# %%
df2
# Out:
#    iq  age  marks
# 0   1    2      3
# 1   1    2      3
# 2   7    8      9

# %%
#using dict

df = {'roll':[1,2,3],'age':[5,6,7],'cls':[8,7,3]}

pd.DataFrame(df)
# Out:
#    roll  age  cls
# 0     1    5    8
# 1     2    6    7
# 2     3    7    3

# %%
df = pd.read_csv('car.csv')

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
#dataframe attributes and methods:

df.shape
# Out:
# (6019, 14)

# %%
df['Location'].values
# Out:
# array(['Mumbai', 'Pune', 'Chennai', ..., 'Jaipur', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
df.head(10)
# Out:
#    Unnamed: 0                                 Name    Location  Year  \
# 0           0               Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                         Honda Jazz V     Chennai  2011
# 3           3                    Maruti Ertiga VDI     Chennai  2012
# 4           4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5           5      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6           6               Nissan Micra Diesel XV      Jaipur  2013
# 7           7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8           8  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9           9       Tata Indica Vista Quadrajet LS     Chennai  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0                                 Name    Location  Year  \
# 6009        6009                  Toyota Camry Hybrid      Mumbai  2015
# 6010        6010                 Honda Brio 1.2 VX MT       Delhi  2013
# 6011        6011              Skoda Superb 3.6 V6 FSI   Hyderabad  2009
# 6012        6012  Toyota Innova 2.5 V Diesel 7-seater  Coimbatore  2011
# 6013        6013                Honda Amaze VX i-DTEC  Coimbatore  2015
# 6014        6014                     Maruti Swift VDI       Delhi  2014
# 6015        6015             Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016                Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                   Maruti Wagon R VXI     Kolkata  2013
# 6018        6018                Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 6009              33500    Petrol    Automatic      First  19.16 kmpl
# ...

# %%
df.sample(5)
# Out:
#       Unnamed: 0                                 Name    Location  Year  \
# 627          627            Hyundai i20 Asta 1.4 CRDi       Delhi  2014
# 603          603  Mercedes-Benz GLC 220d 4MATIC Style      Mumbai  2018
# 5363        5363               Mahindra XUV500 W8 2WD  Coimbatore  2018
# 2922        2922        Toyota Platinum Etios 1.4 GXD   Hyderabad  2015
# 2464        2464           Tata Zest Revotron 1.2T XE       Delhi  2017
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 627               67407    Diesel       Manual      First  21.27 kmpl
# 603               10003    Diesel    Automatic      First   17.9 kmpl
# 5363              46811    Diesel       Manual      First   16.0 kmpl
# 2922             150000    Diesel       Manual      First  23.59 kmpl
# 2464              47000    Petrol       Manual     Second  17.57 kmpl
#
#        Engine      Power  Seats   New_Price  Price
# 627   1396 CC  88.76 bhp    5.0         NaN   4.65
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6019, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats        Price
# count  6019.000000  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   3009.000000  2013.358199       5.873838e+04     5.278735     9.479468
# std    1737.679967     3.269742       9.126884e+04     0.808840    11.187917
# min       0.000000  1998.000000       1.710000e+02     0.000000     0.440000
# 25%    1504.500000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3009.000000  2014.000000       5.300000e+04     5.000000     5.640000
# 75%    4513.500000  2016.000000       7.300000e+04     5.000000     9.950000
# max    6018.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.mean()
# Out:
# <ipython-input-54-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0            3009.000000
# Year                  2013.358199
# Kilometers_Driven    58738.380296
# Seats                    5.278735
# Price                    9.479468
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-55-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Unnamed: 0            3009.00
# Year                  2014.00
# Kilometers_Driven    53000.00
# Seats                    5.00
# Price                    5.64
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-56-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Unnamed: 0           3.019532e+06
# Year                 1.069121e+01
# Kilometers_Driven    8.330002e+09
# Seats                6.542214e-01
# Price                1.251695e+02
# dtype: float64

# %%
df[['Name','Year']] #fancing indexing
# Out:
#                                   Name  Year
# 0               Maruti Wagon R LXI CNG  2010
# 1     Hyundai Creta 1.6 CRDi SX Option  2015
# 2                         Honda Jazz V  2011
# 3                    Maruti Ertiga VDI  2012
# 4      Audi A4 New 2.0 TDI Multitronic  2013
# ...                                ...   ...
# 6014                  Maruti Swift VDI  2014
# 6015          Hyundai Xcent 1.1 CRDi S  2015
# 6016             Mahindra Xylo D4 BSIV  2012
# 6017                Maruti Wagon R VXI  2013
# 6018             Chevrolet Beat Diesel  2011
#
# [6019 rows x 2 columns]

# %%
#accessing the elements
#1. iloc search using index position
#2. loc #seaarch based on location

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                0
# Name                 Maruti Wagon R LXI CNG
# Location                             Mumbai
# Year                                   2010
# Kilometers_Driven                     72000
# Fuel_Type                               CNG
# Transmission                         Manual
# Owner_Type                            First
# Mileage                          26.6 km/kg
# Engine                               998 CC
# Power                             58.16 bhp
# Seats                                   5.0
# New_Price                               NaN
# Price                                  1.75
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Unnamed: 0                              Name Location  Year  \
# 0           0            Maruti Wagon R LXI CNG   Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015
# 2           2                      Honda Jazz V  Chennai  2011
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50

# %%
df.iloc[509]
# Out:
# Unnamed: 0                                 509
# Name                 Mahindra XUV500 AT W8 FWD
# Location                             Bangalore
# Year                                      2015
# Kilometers_Driven                        34000
# Fuel_Type                               Diesel
# Transmission                         Automatic
# Owner_Type                               First
# Mileage                              16.0 kmpl
# Engine                                 2179 CC
# Power                                  140 bhp
# Seats                                      7.0
# New_Price                                  NaN
# Price                                     13.0
# Name: 509, dtype: object

# %%
df.iloc[[0,1,2,3]]
# Out:
#    Unnamed: 0                              Name Location  Year  \
# 0           0            Maruti Wagon R LXI CNG   Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015
# 2           2                      Honda Jazz V  Chennai  2011
# 3           3                 Maruti Ertiga VDI  Chennai  2012
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00

# %%
df.loc[0]
# Out:
# Unnamed: 0                                0
# Name                 Maruti Wagon R LXI CNG
# Location                             Mumbai
# Year                                   2010
# Kilometers_Driven                     72000
# Fuel_Type                               CNG
# Transmission                         Manual
# Owner_Type                            First
# Mileage                          26.6 km/kg
# Engine                               998 CC
# Power                             58.16 bhp
# Seats                                   5.0
# New_Price                               NaN
# Price                                  1.75
# Name: 0, dtype: object

# %%
df.iloc[0:3,1:4]
# Out:
#                                Name Location  Year
# 0            Maruti Wagon R LXI CNG   Mumbai  2010
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015
# 2                      Honda Jazz V  Chennai  2011

# %%
df.loc[0:3,['Name','Year']]
# Out:
#                                Name  Year
# 0            Maruti Wagon R LXI CNG  2010
# 1  Hyundai Creta 1.6 CRDi SX Option  2015
# 2                      Honda Jazz V  2011
# 3                 Maruti Ertiga VDI  2012

# %%
# more function

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.value_counts()
# Out:
# Unnamed: 0  Name                             Location    Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  Mileage      Engine   Power       Seats  New_Price   Price
# 2           Honda Jazz V                     Chennai     2011  46000              Petrol     Manual        First       18.2 kmpl    1199 CC  88.7 bhp    5.0    8.61 Lakh   4.50     1
# 4104        Skoda Superb Style 1.8 TSI AT    Coimbatore  2016  54253              Petrol     Automatic     First       14.67 kmpl   1798 CC  177.46 bhp  5.0    30.19 Lakh  16.81    1
# 4022        Toyota Corolla Altis 1.8 GL      Chennai     2009  32000              Petrol     Manual        Second      14.28 kmpl   1798 CC  138.03 bhp  5.0    22.66 Lakh  4.95     1
# 4026        Maruti Alto K10 VXI              Jaipur      2016  51264              Petrol     Manual        First       24.07 kmpl   998 CC   67.1 bhp    5.0    4.24 Lakh   3.20     1
# ...

# %%
df2.value_counts()
# Out:
# iq  age  marks
# 1   2    3        2
# 7   8    9        1
# dtype: int64

# %%
df2
# Out:
#    iq  age  marks
# 0   1    2      3
# 1   1    2      3
# 2   7    8      9

# %%
df.sort_values('Year',ascending=False)
# Out:
#       Unnamed: 0                                    Name    Location  Year  \
# 4603        4603  Maruti Eeco 5 STR With AC Plus HTR CNG       Kochi  2019
# 5158        5158         Mercedes-Benz CLA 200 CDI Sport       Kochi  2019
# 4131        4131              Toyota Fortuner 2.8 2WD MT  Coimbatore  2019
# 3705        3705     Mercedes-Benz GLC 220d 4MATIC Style  Coimbatore  2019
# 4978        4978                Honda Amaze V CVT Petrol       Kochi  2019
# ...          ...                                     ...         ...   ...
# 1845        1845                      Honda City 1.3 EXI        Pune  1999
# 3749        3749       Mercedes-Benz E-Class 250 D W 210      Mumbai  1998
# 5716        5716                           Maruti Zen LX      Jaipur  1998
# 3138        3138                          Maruti Zen LXI      Jaipur  1998
# 4709        4709                          Maruti 1000 AC   Hyderabad  1998
#
# ...

# %%
df.sort_index()
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df['Mileage'].dropna(how=any)
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df['Mileage'].fillna('avi')
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...
